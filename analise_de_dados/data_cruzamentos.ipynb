# %%
import pandas as pd
import json

# %%
from main import modelo_cruzamentos
# with open("../dados/modelo_cruzamentos.json") as f:
#     data = json.load(f)
data = modelo_cruzamentos

cruzamentos_pal = (data["time"]["1"]["rupturas"])
cruzamentos_red = (data["time"]["5"]["rupturas"])

# %%
num_cruzamentos_pal = 0
for cruzamento in cruzamentos_pal:
    num_cruzamentos_pal += 1
    print(cruzamento)
print("Número de cruzamentos do Palmeiras: ", num_cruzamentos_pal)
# Out:
# {'instante_cruzamento': '00:10:15', 'numero_jogadores_time_cruzando': '7', 'nome_jogadores_time_cruzando': 'Dudu', 'quantidade_jogadores_time_atacando': 1, 'numero_jogadores_time_defendendo': '7, 34, 26', 'nome_jogadores_time_defendendo': 'Eric Ramires, J,. Hurtado, E. Santos', 'quantidade_jogadores_defendendo': 3, 'desfecho': 'Perdido', 'zona': 'D2.1'}
# {'instante_cruzamento': '00:15:05', 'numero_jogadores_time_cruzando': '15, 6, 7, 35', 'nome_jogadores_time_cruzando': 'G. Gomez, Vanderlan, Dudu, Fabinho', 'quantidade_jogadores_time_atacando': 4, 'numero_jogadores_time_defendendo': '17, 19, 11, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bem-Sucedido', 'zona': 'D2.2'}
# {'instante_cruzamento': '00:18:26', 'numero_jogadores_time_cruzando': '7, 10', 'nome_jogadores_time_cruzando': 'Dudu, Rony', 'quantidade_jogadores_time_atacando': 2, 'numero_jogadores_time_defendendo': '4, 26, 34', 'nome_jogadores_time_defendendo': 'Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 3, 'desfecho': 'Bloqueado', 'zona': 'D1.2'}
# {'instante_cruzamento': '00:27:08', 'numero_jogadores_time_cruzando': '15, 13, 14, 10, 35', 'nome_jogadores_time_cruzando': 'G. Gomez, Luan, Artur, Rony, Fabinho', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '17, 19, 11, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bem-Sucedido', 'zona': 'D2.2'}
# {'instante_cruzamento': '00:32:16', 'numero_jogadores_time_cruzando': '23, 6, 14, 10', 'nome_jogadores_time_cruzando': 'R. Veiga, Vanderlan, Artur, Rony', 'quantidade_jogadores_time_atacando': 4, 'numero_jogadores_time_defendendo': '17, 35, 7, 4, 34, 26, 29, ', 'nome_jogadores_time_defendendo': 'B. Goncalves , Matheus Fernandes, Eric Ramires, Natan, J,. Hurtado, E. Santos, Juninho Capixaba ', 'quantidade_jogadores_defendendo': 7, 'desfecho': 'Bloqueado', 'zona': 'D2.2'}
# {'instante_cruzamento': '00:32:54', 'numero_jogadores_time_cruzando': '15, 13, 14, 10, 35', 'nome_jogadores_time_cruzando': 'G. Gomez, Luan, Artur, Rony, Fabinho', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '17, 19, 11, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Perdido', 'zona': 'D2.2'}
# {'instante_cruzamento': '00:33:34', 'numero_jogadores_time_cruzando': '15, 13, 14, 10, 35', 'nome_jogadores_time_cruzando': 'G. Gomez, Luan, Artur, Rony, Fabinho', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '17, 19, 11, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bloqueado', 'zona': 'E2.2'}
# {'instante_cruzamento': '00:34:16', 'numero_jogadores_time_cruzando': '10, 13, 15', 'nome_jogadores_time_cruzando': 'Rony, Luan, G. Gomez', 'quantidade_jogadores_time_atacando': 3, 'numero_jogadores_time_defendendo': '8, 4, 29, 26, 19, 11', 'nome_jogadores_time_defendendo': 'L. Evangelista, Natan, Juninho Capixaba , E. Santos, Sasha, Helinho', 'quantidade_jogadores_defendendo': 6, 'desfecho': 'Bem-Sucedido', 'zona': 'E1.1'}
# {'instante_cruzamento': '00:34:32', 'numero_jogadores_time_cruzando': '10, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '11, 4, 34, 29, 26, 35, 8', 'nome_jogadores_time_defendendo': 'Helinho, Natan, J,. Hurtado, Juninho Capixaba , E. Santos, Matheus Fernandes, L. Evangelista', 'quantidade_jogadores_defendendo': 7, 'desfecho': 'Bloqueado', 'zona': 'D2.2'}
# {'instante_cruzamento': '00:34:46', 'numero_jogadores_time_cruzando': '10, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '19, 34, 4, 26, 29, 35, 8', 'nome_jogadores_time_defendendo': 'Sasha, J,. Hurtado, Natan, E. Santos, Juninho Capixaba , Matheus Fernandes, L. Evangelista', 'quantidade_jogadores_defendendo': 7, 'desfecho': 'Bem-Sucedido', 'zona': 'D2.2'}
# {'instante_cruzamento': '00:50:36', 'numero_jogadores_time_cruzando': '10, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '17, 19, 11, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bem-Sucedido', 'zona': 'E2.2'}
# {'instante_cruzamento': '00:54:48', 'numero_jogadores_time_cruzando': '10, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '17, 19, 11, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bloqueado', 'zona': 'E2.2'}
# {'instante_cruzamento': '00:55:14', 'numero_jogadores_time_cruzando': '10, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '17, 19, 11, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bloqueado', 'zona': 'E2.2'}
# {'instante_cruzamento': '01:01:34', 'numero_jogadores_time_cruzando': '10, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '28, 19, 16, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bloqueado', 'zona': 'E2.2'}
# {'instante_cruzamento': '01:01:54', 'numero_jogadores_time_cruzando': '10, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '28, 19, 16, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Perdido', 'zona': 'E2.2'}
# {'instante_cruzamento': '01:06:20', 'numero_jogadores_time_cruzando': '9, 13, 35, 15, 14', 'nome_jogadores_time_cruzando': 'Endrick , Luan, Fabinho, G. Gomez, Artur', 'quantidade_jogadores_time_atacando': 5, 'numero_jogadores_time_defendendo': '28, 19, 16, 7, 35, 8, 29, 4, 26, 34', 'nome_jogadores_time_defendendo': 'Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bem-Sucedido', 'zona': 'D2.2'}
# {'instante_cruzamento': '01:24:42', 'numero_jogadores_time_cruzando': '19', 'nome_jogadores_time_cruzando': 'Breno Lopes ', 'quantidade_jogadores_time_atacando': 1, 'numero_jogadores_time_defendendo': '13, 26', 'nome_jogadores_time_defendendo': 'Aderlan, E. Santos', 'quantidade_jogadores_defendendo': 2, 'desfecho': 'Perdido', 'zona': 'D3'}
# {'instante_cruzamento': '01:33:05', 'numero_jogadores_time_cruzando': '11, 13, 15, 18, 9, 27', 'nome_jogadores_time_cruzando': 'Tabata, Luan, G. Gomez, Flaco Lopez, Endrick , Richard Rios', 'quantidade_jogadores_time_atacando': 6, 'numero_jogadores_time_defendendo': '26, 29, 35, 7, 19, 2, 9, 13, 16, 28', 'nome_jogadores_time_defendendo': 'E. Santos, Juninho Capixaba , Matheus Fernandes, Eric Ramires, Sasha, Leo Realpe, Alerrandro, Aderlan, Henry, Vitor Hugo', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bloqueado', 'zona': 'E2.2'}
# {'instante_cruzamento': '01:35:12', 'numero_jogadores_time_cruzando': '11, 13, 15, 18, 9, 27', 'nome_jogadores_time_cruzando': 'Tabata, Luan, G. Gomez, Flaco Lopez, Endrick , Richard Rios', 'quantidade_jogadores_time_atacando': 6, 'numero_jogadores_time_defendendo': '26, 29, 35, 7, 19, 2, 9, 13, 16, 28', 'nome_jogadores_time_defendendo': 'E. Santos, Juninho Capixaba , Matheus Fernandes, Eric Ramires, Sasha, Leo Realpe, Alerrandro, Aderlan, Henry, Vitor Hugo', 'quantidade_jogadores_defendendo': 10, 'desfecho': 'Bloqueado', 'zona': 'E2.2'}
# {'instante_cruzamento': '01:35:25', 'numero_jogadores_time_cruzando': '11, 13, 15, 9, 19, 18, 27', 'nome_jogadores_time_cruzando': 'Tabata, Luan, G. Gomez, Endrick , Breno Lopes , Flaco Lopez, Richard Rios', 'quantidade_jogadores_time_atacando': 7, 'numero_jogadores_time_defendendo': '35, 26, 7, 2, 13, 29', 'nome_jogadores_time_defendendo': 'Matheus Fernandes, E. Santos, Eric Ramires, Leo Realpe, Aderlan, Juninho Capixaba ', 'quantidade_jogadores_defendendo': 6, 'desfecho': 'Bem-Sucedido', 'zona': 'D2.1'}
# {'instante_cruzamento': '01:36:17', 'numero_jogadores_time_cruzando': '9, 18, 19', 'nome_jogadores_time_cruzando': 'Endrick , Flaco Lopez, Breno Lopes ', 'quantidade_jogadores_time_atacando': 3, 'numero_jogadores_time_defendendo': '13, 2, 29, 26', 'nome_jogadores_time_defendendo': 'Aderlan, Leo Realpe, Juninho Capixaba , E. Santos', 'quantidade_jogadores_defendendo': 4, 'desfecho': 'Bloqueado', 'zona': 'E1.2'}
# Número de cruzamentos do Palmeiras:  21

# %%
dic_cruzamentos_pal = {} 

for cruzamento in cruzamentos_pal:
    cruzamento_instante = cruzamento["instante_cruzamento"]

    dic_cruzamentos_pal[cruzamento_instante] = {
        "nome_jogadores_time_cruzando": cruzamento["nome_jogadores_time_cruzando"],
        "nome_jogadores_time_defendendo": cruzamento["nome_jogadores_time_defendendo"],
        "desfecho": cruzamento["desfecho"],
        "zona": cruzamento["zona"]
    }

dic_cruzamentos_pal
# Out:
# {'00:10:15': {'nome_jogadores_time_cruzando': 'Dudu',
#   'nome_jogadores_time_defendendo': 'Eric Ramires, J,. Hurtado, E. Santos',
#   'desfecho': 'Perdido',
#   'zona': 'D2.1'},
#  '00:15:05': {'nome_jogadores_time_cruzando': 'G. Gomez, Vanderlan, Dudu, Fabinho',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bem-Sucedido',
#   'zona': 'D2.2'},
#  '00:18:26': {'nome_jogadores_time_cruzando': 'Dudu, Rony',
#   'nome_jogadores_time_defendendo': 'Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bloqueado',
#   'zona': 'D1.2'},
#  '00:27:08': {'nome_jogadores_time_cruzando': 'G. Gomez, Luan, Artur, Rony, Fabinho',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bem-Sucedido',
#   'zona': 'D2.2'},
#  '00:32:16': {'nome_jogadores_time_cruzando': 'R. Veiga, Vanderlan, Artur, Rony',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Matheus Fernandes, Eric Ramires, Natan, J,. Hurtado, E. Santos, Juninho Capixaba ',
#   'desfecho': 'Bloqueado',
#   'zona': 'D2.2'},
#  '00:32:54': {'nome_jogadores_time_cruzando': 'G. Gomez, Luan, Artur, Rony, Fabinho',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Perdido',
#   'zona': 'D2.2'},
#  '00:33:34': {'nome_jogadores_time_cruzando': 'G. Gomez, Luan, Artur, Rony, Fabinho',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bloqueado',
#   'zona': 'E2.2'},
#  '00:34:16': {'nome_jogadores_time_cruzando': 'Rony, Luan, G. Gomez',
#   'nome_jogadores_time_defendendo': 'L. Evangelista, Natan, Juninho Capixaba , E. Santos, Sasha, Helinho',
#   'desfecho': 'Bem-Sucedido',
#   'zona': 'E1.1'},
#  '00:34:32': {'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'Helinho, Natan, J,. Hurtado, Juninho Capixaba , E. Santos, Matheus Fernandes, L. Evangelista',
#   'desfecho': 'Bloqueado',
#   'zona': 'D2.2'},
#  '00:34:46': {'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'Sasha, J,. Hurtado, Natan, E. Santos, Juninho Capixaba , Matheus Fernandes, L. Evangelista',
#   'desfecho': 'Bem-Sucedido',
#   'zona': 'D2.2'},
#  '00:50:36': {'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bem-Sucedido',
#   'zona': 'E2.2'},
#  '00:54:48': {'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bloqueado',
#   'zona': 'E2.2'},
#  '00:55:14': {'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'B. Goncalves , Sasha, Helinho, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bloqueado',
#   'zona': 'E2.2'},
#  '01:01:34': {'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bloqueado',
#   'zona': 'E2.2'},
#  '01:01:54': {'nome_jogadores_time_cruzando': 'Rony, Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Perdido',
#   'zona': 'E2.2'},
#  '01:06:20': {'nome_jogadores_time_cruzando': 'Endrick , Luan, Fabinho, G. Gomez, Artur',
#   'nome_jogadores_time_defendendo': 'Vitor Hugo, Sasha, Henry, Eric Ramires, Matheus Fernandes, L. Evangelista, Juninho Capixaba , Natan, E. Santos, J,. Hurtado',
#   'desfecho': 'Bem-Sucedido',
#   'zona': 'D2.2'},
#  '01:24:42': {'nome_jogadores_time_cruzando': 'Breno Lopes ',
#   'nome_jogadores_time_defendendo': 'Aderlan, E. Santos',
#   'desfecho': 'Perdido',
#   'zona': 'D3'},
#  '01:33:05': {'nome_jogadores_time_cruzando': 'Tabata, Luan, G. Gomez, Flaco Lopez, Endrick , Richard Rios',
#   'nome_jogadores_time_defendendo': 'E. Santos, Juninho Capixaba , Matheus Fernandes, Eric Ramires, Sasha, Leo Realpe, Alerrandro, Aderlan, Henry, Vitor Hugo',
#   'desfecho': 'Bloqueado',
#   'zona': 'E2.2'},
#  '01:35:12': {'nome_jogadores_time_cruzando': 'Tabata, Luan, G. Gomez, Flaco Lopez, Endrick , Richard Rios',
#   'nome_jogadores_time_defendendo': 'E. Santos, Juninho Capixaba , Matheus Fernandes, Eric Ramires, Sasha, Leo Realpe, Alerrandro, Aderlan, Henry, Vitor Hugo',
#   'desfecho': 'Bloqueado',
#   'zona': 'E2.2'},
#  '01:35:25': {'nome_jogadores_time_cruzando': 'Tabata, Luan, G. Gomez, Endrick , Breno Lopes , Flaco Lopez, Richard Rios',
#   'nome_jogadores_time_defendendo': 'Matheus Fernandes, E. Santos, Eric Ramires, Leo Realpe, Aderlan, Juninho Capixaba ',
#   'desfecho': 'Bem-Sucedido',
#   'zona': 'D2.1'},
#  '01:36:17': {'nome_jogadores_time_cruzando': 'Endrick , Flaco Lopez, Breno Lopes ',
#   'nome_jogadores_time_defendendo': 'Aderlan, Leo Realpe, Juninho Capixaba , E. Santos',
#   'desfecho': 'Bloqueado',
#   'zona': 'E1.2'}}

# %%
df_pal = pd.DataFrame(dic_cruzamentos_pal)
df_pal = df_pal.transpose()
df_pal['instante_inicial'] = df_pal.index
df_pal.reset_index(drop=True, inplace=True)
df_pal
# Out:
#                          nome_jogadores_time_cruzando  \
# 0                                                Dudu
# 1                  G. Gomez, Vanderlan, Dudu, Fabinho
# 2                                          Dudu, Rony
# 3                G. Gomez, Luan, Artur, Rony, Fabinho
# 4                    R. Veiga, Vanderlan, Artur, Rony
# 5                G. Gomez, Luan, Artur, Rony, Fabinho
# 6                G. Gomez, Luan, Artur, Rony, Fabinho
# 7                                Rony, Luan, G. Gomez
# 8                Rony, Luan, Fabinho, G. Gomez, Artur
# 9                Rony, Luan, Fabinho, G. Gomez, Artur
# 10               Rony, Luan, Fabinho, G. Gomez, Artur
# 11               Rony, Luan, Fabinho, G. Gomez, Artur
# 12               Rony, Luan, Fabinho, G. Gomez, Artur
# 13               Rony, Luan, Fabinho, G. Gomez, Artur
# 14               Rony, Luan, Fabinho, G. Gomez, Artur
# 15           Endrick , Luan, Fabinho, G. Gomez, Artur
# 16                                       Breno Lopes
# 17  Tabata, Luan, G. Gomez, Flaco Lopez, Endrick ,...
# 18  Tabata, Luan, G. Gomez, Flaco Lopez, Endrick ,...
# 19  Tabata, Luan, G. Gomez, Endrick , Breno Lopes ...
# 20                Endrick , Flaco Lopez, Breno Lopes
#
#                        nome_jogadores_time_defendendo      desfecho  zona  \
# 0                Eric Ramires, J,. Hurtado, E. Santos       Perdido  D2.1
# 1   B. Goncalves , Sasha, Helinho, Eric Ramires, M...  Bem-Sucedido  D2.2
# 2                       Natan, E. Santos, J,. Hurtado     Bloqueado  D1.2
# 3   B. Goncalves , Sasha, Helinho, Eric Ramires, M...  Bem-Sucedido  D2.2
# 4   B. Goncalves , Matheus Fernandes, Eric Ramires...     Bloqueado  D2.2
# 5   B. Goncalves , Sasha, Helinho, Eric Ramires, M...       Perdido  D2.2
# 6   B. Goncalves , Sasha, Helinho, Eric Ramires, M...     Bloqueado  E2.2
# 7   L. Evangelista, Natan, Juninho Capixaba , E. S...  Bem-Sucedido  E1.1
# 8   Helinho, Natan, J,. Hurtado, Juninho Capixaba ...     Bloqueado  D2.2
# 9   Sasha, J,. Hurtado, Natan, E. Santos, Juninho ...  Bem-Sucedido  D2.2
# 10  B. Goncalves , Sasha, Helinho, Eric Ramires, M...  Bem-Sucedido  E2.2
# 11  B. Goncalves , Sasha, Helinho, Eric Ramires, M...     Bloqueado  E2.2
# 12  B. Goncalves , Sasha, Helinho, Eric Ramires, M...     Bloqueado  E2.2
# 13  Vitor Hugo, Sasha, Henry, Eric Ramires, Matheu...     Bloqueado  E2.2
# 14  Vitor Hugo, Sasha, Henry, Eric Ramires, Matheu...       Perdido  E2.2
# 15  Vitor Hugo, Sasha, Henry, Eric Ramires, Matheu...  Bem-Sucedido  D2.2
# 16                                 Aderlan, E. Santos       Perdido    D3
# 17  E. Santos, Juninho Capixaba , Matheus Fernande...     Bloqueado  E2.2
# 18  E. Santos, Juninho Capixaba , Matheus Fernande...     Bloqueado  E2.2
# 19  Matheus Fernandes, E. Santos, Eric Ramires, Le...  Bem-Sucedido  D2.1
# 20  Aderlan, Leo Realpe, Juninho Capixaba , E. Santos     Bloqueado  E1.2
#
#    instante_inicial
# 0          00:10:15
# 1          00:15:05
# 2          00:18:26
# 3          00:27:08
# 4          00:32:16
# 5          00:32:54
# 6          00:33:34
# 7          00:34:16
# 8          00:34:32
# 9          00:34:46
# 10         00:50:36
# 11         00:54:48
# 12         00:55:14
# 13         01:01:34
# 14         01:01:54
# 15         01:06:20
# 16         01:24:42
# 17         01:33:05
# 18         01:35:12
# 19         01:35:25
# 20         01:36:17

# %%
# Destaques em participações em cruzamentos do Palmeiras
df_nome_jogadores_time_cruzando_pal = df_pal['nome_jogadores_time_cruzando']

dic_nome_jogadores_time_cruzando_pal = {}

for nome_jogador in df_nome_jogadores_time_cruzando_pal:
    # Remover espaços extras no início e no final
    nome_jogador = nome_jogador.strip()
    # Espaços antes e depois das vírgulas
    nome_jogador = nome_jogador.replace(" , ", ",")
    # Tirar espaços em branco depois das vírgulas
    nome_jogador = nome_jogador.replace(", ", ",")
    # Ou espaço antes das vírgulas
    nome_jogador = nome_jogador.replace(" ,", ",")
    # Separar os nomes
    nomes = nome_jogador.split(",")
    for nome in nomes:
        # Remover espaços extras no início e no final de cada nome
        nome = nome.strip()
        if nome not in dic_nome_jogadores_time_cruzando_pal:
            dic_nome_jogadores_time_cruzando_pal[nome] = 1
        else:
            dic_nome_jogadores_time_cruzando_pal[nome] += 1

# %%
df_destaques_pal = pd.DataFrame(dic_nome_jogadores_time_cruzando_pal.items(), columns=['nome_jogador', 'num_participacoes_em_cruzamentos'])
df_destaques_pal = df_destaques_pal.sort_values(by='num_participacoes_em_cruzamentos', ascending=False)
df_destaques_pal = df_destaques_pal.reset_index(drop=True)
df_destaques_pal
# Out:
#     nome_jogador  num_participacoes_em_cruzamentos
# 0       G. Gomez                                16
# 1           Luan                                15
# 2           Rony                                13
# 3        Fabinho                                12
# 4          Artur                                12
# 5        Endrick                                 5
# 6    Flaco Lopez                                 4
# 7           Dudu                                 3
# 8    Breno Lopes                                 3
# 9         Tabata                                 3
# 10  Richard Rios                                 3
# 11     Vanderlan                                 2
# 12      R. Veiga                                 1

# %% [markdown]
# Bragantino

# %%
num_cruzamentos_red = 0
for cruzamento in cruzamentos_red:
    num_cruzamentos_red += 1

# %%
dic_cruzamentos_red = {} 

for cruzamento in cruzamentos_red:
    cruzamento_instante = cruzamento["instante_cruzamento"]

    dic_cruzamentos_red[cruzamento_instante] = {
        "nome_jogadores_time_cruzando": cruzamento["nome_jogadores_time_cruzando"],
        "nome_jogadores_time_defendendo": cruzamento["nome_jogadores_time_defendendo"],
        "desfecho": cruzamento["desfecho"],
        "zona": cruzamento["zona"]
    }

df_red = pd.DataFrame(dic_cruzamentos_red)
df_red = df_red.transpose()
df_red['instante_inicial'] = df_red.index
df_red.reset_index(drop=True, inplace=True)
df_red
# Out:
#                         nome_jogadores_time_cruzando  \
# 0                 Eric Ramires, Sasha, B. Goncalves
# 1  Juninho Capixaba , Natan, E. Santos, Sasha, B....
# 2  B. Goncalves , Juninho Capixaba , Sasha, E. Sa...
# 3             Sasha, B. Goncalves , E. Santos, Natan
# 4  E. Santos, Natan, B. Goncalves , Sasha, J,. Hu...
# 5  E. Santos, Natan, B. Goncalves , Sasha, J,. Hu...
# 6                                              Sasha
# 7  E. Santos, Natan, Helinho, Sasha, J,. Hurtado,...
# 8  Leo Realpe, Sasha, Alerrandro, Henry, Vitor Hu...
#
#                       nome_jogadores_time_defendendo      desfecho  zona  \
# 0        Luan, G. Gomez, Mayke, Vanderlan, G. Menino  Bem-Sucedido  D2.1
# 1  Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. ...  Bem-Sucedido  D1.1
# 2  Mayke, Luan, G. Gomez, Vanderlan, G. Menino, F...       Perdido  D2.2
# 3  Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. ...       Perdido  E1.1
# 4  Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. ...     Bloqueado  D2.2
# 5  Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. ...     Bloqueado  D2.2
# 6                                     Luan, G. Gomez  Bem-Sucedido  E1.1
# 7  Mayke, Luan, G. Gomez, Vanderlan, Fabinho, G. ...     Bloqueado  E2.2
# 8  Mayke, Luan, G. Gomez, Vanderlan, Richard Rios...     Bloqueado  D2.2
#
#   instante_inicial
# 0         00:01:08
# 1         00:02:47
# 2         00:09:07
# 3         00:12:21
# 4         00:21:53
# 5         00:22:13
# 6         00:24:11
# 7         00:25:50
# 8         01:20:00

# %%
# Destaques em participações em cruzamentos do Bragantino
df_nome_jogadores_time_cruzando_red = df_red['nome_jogadores_time_cruzando']

dic_nome_jogadores_time_cruzando_red = {}

for nome_jogador in df_nome_jogadores_time_cruzando_red:
    # Remover espaços extras no início e no final
    nome_jogador = nome_jogador.strip()
    # Espaços antes e depois das vírgulas
    nome_jogador = nome_jogador.replace(" , ", ",")
    # Tirar espaços em branco depois das vírgulas
    nome_jogador = nome_jogador.replace(", ", ",")
    # Ou espaço antes das vírgulas
    nome_jogador = nome_jogador.replace(" ,", ",")
    # Separar os nomes
    nomes = nome_jogador.split(",")
    for nome in nomes:
        # Remover espaços extras no início e no final de cada nome
        nome = nome.strip()
        if nome not in dic_nome_jogadores_time_cruzando_red:
            dic_nome_jogadores_time_cruzando_red[nome] = 1
        else:
            dic_nome_jogadores_time_cruzando_red[nome] += 1

# DataFrame de destaques em participações em cruzamentos do Bragantino
df_destaques_red = pd.DataFrame(dic_nome_jogadores_time_cruzando_red.items(), columns=['nome_jogador', 'num_participacoes_em_cruzamentos'])
df_destaques_red = df_destaques_red.sort_values(by='num_participacoes_em_cruzamentos', ascending=False)
df_destaques_red = df_destaques_red.reset_index(drop=True)
df_destaques_red
# Out:
#         nome_jogador  num_participacoes_em_cruzamentos
# 0              Sasha                                 9
# 1          E. Santos                                 7
# 2       B. Goncalves                                 6
# 3              Natan                                 6
# 4   Juninho Capixaba                                 5
# 5                  J                                 3
# 6          . Hurtado                                 3
# 7       Eric Ramires                                 1
# 8            Helinho                                 1
# 9         Leo Realpe                                 1
# 10        Alerrandro                                 1
# 11             Henry                                 1
# 12        Vitor Hugo                                 1

# %%
desfechos_cruzamentos_pal = df_pal['desfecho']
desfechos_cruzamentos_pal
# Out:
# 0          Perdido
# 1     Bem-Sucedido
# 2        Bloqueado
# 3     Bem-Sucedido
# 4        Bloqueado
# 5          Perdido
# 6        Bloqueado
# 7     Bem-Sucedido
# 8        Bloqueado
# 9     Bem-Sucedido
# 10    Bem-Sucedido
# 11       Bloqueado
# 12       Bloqueado
# 13       Bloqueado
# 14         Perdido
# 15    Bem-Sucedido
# 16         Perdido
# 17       Bloqueado
# 18       Bloqueado
# 19    Bem-Sucedido
# 20       Bloqueado
# Name: desfecho, dtype: object

# %%
desfechos_cruzamentos_red = df_red['desfecho']
# reset index
desfechos_cruzamentos_red = desfechos_cruzamentos_red.reset_index(drop=True)
desfechos_cruzamentos_red = desfechos_cruzamentos_red.to_dict()
quant_desfechos_cruzamentos_red = {}
for desfecho in desfechos_cruzamentos_red.values():
    if desfecho not in quant_desfechos_cruzamentos_red:
        quant_desfechos_cruzamentos_red[desfecho] = 1
    else:
        quant_desfechos_cruzamentos_red[desfecho] += 1
quant_desfechos_cruzamentos_red
# Out:
# {'Bem-Sucedido': 3, 'Perdido': 2, 'Bloqueado': 4}
